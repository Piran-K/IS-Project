# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import csv

# %%
input_url = "https://www.tripadvisor.in/Tourism-g297604-Goa-Vacations.html"
num_attractions_per_city = 100
num_reviews_per_attraction = 100
city_name = input_url[input_url.find("Tourism-g")+16:input_url.find("-Vacations")]

# %%
city_code = input_url[input_url.find("Tourism-g")+8:input_url.find("-" + city_name)]

city_url = "https://www.tripadvisor.in/Attractions-" + city_code + "-Activities-oa0-" +city_name + ".html"
domain = city_url[:city_url.find("Attractions-g")-1]

city_url1 = city_url[:city_url.find("Activities-oa")+13]
city_url2 = city_url[city_url.find("Activities-oa")+14:]

city_urls = [(city_url1 + str(i) + city_url2) for i in list(map(lambda x: 30 * x, range(1, 1000)))]
city_urls.insert(0, city_url)

attraction_urls = []

for ind, url in enumerate(city_urls):
    page = requests.get(url, headers={'User-Agent': "Mozilla/5.0"})
    soup = BeautifulSoup(page.text, 'html.parser')
    d = soup.find("div", class_="DDJze")
    att_urls_on_page = d.find_all("div", class_="alPVI eNNhq PgLKC tnGGX")
    length = len(att_urls_on_page)
    if (length == 0):
        break
    for i in range(length):
        attraction_urls.append(domain + att_urls_on_page[i].find_all('a')[0].get('href'))
        
city_attraction_urls = pd.DataFrame(attraction_urls, columns = ['attraction_urls'])
city_attraction_urls.to_csv(city_name + "_Attraction_Urls.csv")

# %%
city_attraction_urls = pd.read_csv(city_name + "_Attraction_Urls.csv")

attraction_number = 0

for attraction_url in city_attraction_urls.attraction_urls:
    
    attraction_name = attraction_url[attraction_url.find("Reviews")+8:attraction_url.find(city_name)-1]
    print(attraction_number, "  ", attraction_name)
    
    try:
        pd.read_csv("Individual Attractions/" + attraction_name + "_" + city_neme + ".csv")
    except:

        attraction_url1 = attraction_url[:attraction_url.find("Reviews")+8]+"or"
        attraction_url2 = attraction_url[attraction_url.find("Reviews")+7:]

        review_urls = [(attraction_url1 + str(i) + attraction_url2) for i in list(map(lambda x: 10 * x, range(1, 30)))]
        review_urls.insert(0, attraction_url)


        
        review_page_number = 0
        
        for ind, url in enumerate(review_urls):
            page = requests.get(url, headers={'User-Agent': "Mozilla/5.0"})
            soup = BeautifulSoup(page.text, 'html.parser')
                    
            attraction = []
            name_of_reviewer = []
            reviewer_rating = []
            review_date = []
            review_title = []
            review_text = []
            
            d = soup.find("div", class_="LbPSX")
            reviewer_names = d.find_all("div", class_="zpDvc")
            reviewer_ratings =  d.find_all("svg", class_="UctUV d H0")
            review_titles = d.find_all("div", class_="biGQs _P fiohW qWPrE ncFvv fOtGX")
            review_dates = d.find_all("div", class_="RpeCd")
            review_texts =  d.find_all("div", class_="biGQs _P pZUbB KxBGd")
            
            length = len(reviewer_names)
            length1 = len(reviewer_ratings)
            length2 = len(review_dates)
            length3 = len(review_titles)
            length4 = len(review_texts)
            
            if (length == 0):
                break
            try:
                for i in range(length):
                    name_of_reviewer.append(reviewer_names[i].contents[0].contents[0].contents[0])
                    attraction.append(attraction_name)
                for i in range(length1):
                    reviewer_rating.append(reviewer_ratings[i]['aria-label'])
                for i in range(length2):      
                    review_date.append(review_dates[i].contents[0])
                for i in range(length3):
                    review_title.append(review_titles[i].contents[0].contents[0].text)
                for i in range(length4):
                    review_text.append(review_texts[i].contents[0].text)
            except:
                break


            dic = {}
            dic["Tourist Attraction"] = attraction
            dic['Name'] = name_of_reviewer
            dic['Rating'] = reviewer_rating
            dic['Date and criteria'] = review_date
            dic['Title'] = review_title
            dic['Review'] = review_text      
                
            reviews_on_page = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in dic.items() ]))
            
            if (review_page_number==0):
                attraction_reviews  = reviews_on_page[:]
            else:
                attraction_reviews = pd.concat([attraction_reviews,reviews_on_page])
            
            review_page_number = review_page_number+1

        if (attraction_number==0):
            city_reviews = attraction_reviews[:]
        else:
            city_reviews = pd.concat([city_reviews,attraction_reviews])
        
        attraction_reviews.to_csv("Individual Attractions/" + attraction_name + "_" + city_name + ".csv")
    
    attraction_number = attraction_number + 1
    
    city_reviews.to_csv(city_name + "_Attraction_Reviews.csv")
    
city_reviews.to_csv(city_name + "_Attraction_Reviews.csv")

# %%
city_attraction_urls = pd.read_csv(city_name + "_Attraction_Urls.csv")

attraction_number = 0

for attraction_url in city_attraction_urls.attraction_urls:
    
    attraction_name = attraction_url[attraction_url.find("Reviews")+8:attraction_url.find(city_name)-1]
    print(attraction_number, "  ", attraction_name)
    
    try:
        pd.read_csv("Limited Individual Attractions/" + attraction_name + "_" + city_name + ".csv")
        city_reviews = pd.read_csv(city_name + "_Limited_Attraction_Reviews.csv")
    except:

        attraction_url1 = attraction_url[:attraction_url.find("Reviews")+8]+"or"
        attraction_url2 = attraction_url[attraction_url.find("Reviews")+7:]

        review_urls = [(attraction_url1 + str(i) + attraction_url2) for i in list(map(lambda x: 10 * x, range(1, 30)))]
        review_urls.insert(0, attraction_url)

        review_page_number = 0
        
        for ind, url in enumerate(review_urls):
            
            try:
                page = requests.get(url, headers={'User-Agent': "Mozilla/5.0"})
                soup = BeautifulSoup(page.text, 'html.parser')
                        
                attraction = []
                name_of_reviewer = []
                reviewer_rating = []
                review_date = []
                review_title = []
                review_text = []
                
                d = soup.find("div", class_="LbPSX")
                reviewer_names = d.find_all("div", class_="zpDvc")
                reviewer_ratings =  d.find_all("svg", class_="UctUV d H0")
                review_titles = d.find_all("div", class_="biGQs _P fiohW qWPrE ncFvv fOtGX")
                review_dates = d.find_all("div", class_="RpeCd")
                review_texts =  d.find_all("div", class_="biGQs _P pZUbB KxBGd")
                
                length = len(reviewer_names)
                length1 = len(reviewer_ratings)
                length2 = len(review_dates)
                length3 = len(review_titles)
                length4 = len(review_texts)
                
                if (length == 0):
                    break
                try:
                    for i in range(length):
                        name_of_reviewer.append(reviewer_names[i].contents[0].contents[0].contents[0])
                        attraction.append(attraction_name)
                    for i in range(length1):
                        reviewer_rating.append(reviewer_ratings[i]['aria-label'])
                    for i in range(length2):      
                        review_date.append(review_dates[i].contents[0])
                    for i in range(length3):
                        review_title.append(review_titles[i].contents[0].contents[0].text)
                    for i in range(length4):
                        review_text.append(review_texts[i].contents[0].text)
                except:
                    break

                dic = {}
                dic["Tourist Attraction"] = attraction
                dic['Name'] = name_of_reviewer
                dic['Rating'] = reviewer_rating
                dic['Date and criteria'] = review_date
                dic['Title'] = review_title
                dic['Review'] = review_text      
                    
                reviews_on_page = pd.DataFrame(dict([ (k,pd.Series(v)) for k,v in dic.items() ]))
                
                if (review_page_number==0):
                    attraction_reviews  = reviews_on_page[:]
                else:
                    attraction_reviews = pd.concat([attraction_reviews,reviews_on_page])
                
                review_page_number = review_page_number+1
                    
                if len(attraction_reviews) >= num_reviews_per_attraction:
                    break
            except:
                pass

        try:
            city_reviews = pd.concat([city_reviews,attraction_reviews])
        except:
            city_reviews = attraction_reviews[:]
        
        attraction_reviews.to_csv("Limited Individual Attractions/" + attraction_name + "_" + city_name + ".csv", index = False)
    
    attraction_number = attraction_number + 1
    
    city_reviews.to_csv(city_name + "_Limited_Attraction_Reviews.csv", index = False)
    
    if attraction_number == num_attractions_per_city:
        break
    
city_reviews.to_csv(city_name + "_Limited_Attraction_Reviews.csv", index = False)
# Out:
# 0    Palolem_Beach-Canacona_South
# 1    Baga_Beach-Baga_North
# 2    Benaulim_Beach-Benaulim_Salcette_South
# 3    Cavelossim_Beach-Cavelossim_South
# 4    Agonda_Beach-Agonda_South
# 5    Basilica_of_Bom_Jesus
# 6    Varca_Beach-Varca_Salcette_South
# 7    Candolim_Beach-Bardez_North
# 8    Arambol_Beach-Arambol_North
# 9    Calangute_Beach-Calangute_North
# 10    Morjim_Beach-Morjim_North
# 11    Deltin_Royale-Panjim_North
# 12    Dudhsagar_Falls-Mollem_National_Park_South
# 13    Utorda_Beach-Utorda_South
# 14    Big_Daddy_Casino-Panjim_North
# 15    Sheek_Emporium_Armanii_Boutique_Since_1950-Candolim_Bardez_North
# 16    Vagator_Beach-Mapusa_North
# 17    Old
# 18    Mandrem_Beach-Mandrem_North
# 19    Fort_Aguada-Sinquerim_North
# 20    Cola_Beach-Canacona_South
# 21    Colva_Beach-Colva_South
# 22    Fontainhas-Panjim_North
# 23    Sinquerim_Beach-Sinquerim_North
# 24    Anjuna_Beach-Bardez_North
# 25    Anjuna_Market-Anjuna_Bardez_North
# 26    Se_Cathedral-Panjim_North
# 27    Church_of_Our_Lady_of_the_Immaculate_Conception-Panjim_North
# 28    Ashwem_Beach-Morjim_North
# 29    Chapora_Fort-Chapora_North
# 30    Reis_Magos_Fort-Panjim_North
# 31    Mangeshi_Temple
# 32    The_Saturday_Night_Market-Arpora_North
# 33    Tomb_of_St_Francis_Xavier-Old
# 34    Shantadurga_Temple-Panjim_North
# 35    Majorda_Beach-Majorda_South
# 36    Miramar_Beach-Panjim_North
# 37    Sahakari_Spice_Farm-Ponda_North
# 38    Dona_Paula_Beach-Dona_Paula_Panjim_North
# 39    Fort_Aguada_Lighthouse-Bardez_North
# 40    Betalbatim_Beach-Betalbatim_Salcette_South
# 41    Keri_Beach_Querim_Beach-Arambol_North
# 42    Cabo_de_Rama_Fort-Canacona_South
# 43    St_Alex_Church-Calangute_North
# 44    Butterfly_Beach-Palolem_Canacona_South
# 45    Tanshikar_s_Working_Organic_Spice_Farm-Sanguem_South
# 46    Cansaulim_Beach-Cansaulim_South
# 47    Naval_Aviation_Museum-Mormugao_North
# 48    Bogmalo_Beach-Vasco_da_Gama_South
# 49    Galgibaga_Beach-Agonda_South
# 50    Mobor_Beach-Salcette_South
# 51    Tropical_Spice_Plantation-Ponda_North
# 52    Din_Brothers_Jewellers_and_Gold_Smiths-Cavelossim_South
# 53    Divar_Island-Panjim_North
# 54    Arossim_Beach-Cansaulim_South
# 55    Paul_John_Visitor_Centre_John_Distilleries-Cuncolim_South
# 56    Margao_Market-Margao_South
# 57    Deltin_Jaqk-Panjim_North
# 58    Church_of_St_Francis_of_Assissi-Old
# 59    Mapusa_Friday_Bazaar-Mapusa_North
# 60    Museum_of
# 61    St_Cajetan_s_Church-Old
# 62    Chapora_Beach-Arpora_North
# 63    Ozran_Beach-Bardez_North
# 64
# 65    Church_and_Monastery_of_St_Augustine-Panjim_North
# 66    The_Zuri_White_Sands_Casino-Varca_Salcette_South
# 67    Church_of_Our_Lady_Of_Hope-Candolim_Bardez_North
# 68    Salaulim_Dam-Sanguem_South
# 69    Bogmalo_Beach-Bogmalo_South
# 70    Palacio_do_Deao-Quepem_South
# 71    Mandovi_RIver-Panjim_North
# 72    Paliem_Sweet_Water_Lake-Arambol_North
# 73    Coco_Beach-Candolim_Bardez_North
# 74    Church_of_the_Immaculate_Conception_of_the_Virgin_Mary-Panjim_North
# 75    Mall_de
# 76    Dr_Salim_Ali_Bird_Sanctuary-Panjim_North
# 77    Big_Foot_Museum-Loutolim_South
# 78    Patnem_Colomb_Beach-Panjim_North
# 79    Houses_of
# 80    Shri_Mahalasa_Temple-Ponda_North
# 81    Church_of_Holy_Spirit-Margao_South
# 82    Fort_Aguada_Beach
# 83    Mahalaxmi_Temple-Panjim_North
# 84    Rahul_s_Cookery_Classes-Palolem_Canacona_South
# 85    Fort_Terekhol-Tiracol_North
# 86    Tambadi_Surla_Mahadev_Temple-Sanguem_South
# 87    Chapel_of_Our_Lady_of_the_Mount-Panjim_North
# 88    Mae_De_Deus_Church-Saligao_Bardez_North
# 89    Galjibaga_Beach-Canacona_South
# 90    Bondla_Wildlife_Sanctuary
# 91    Mahadeva_Temple-Mollem_National_Park_South
# 92    Zaara_The_Luxury_Spa-Arpora_North
# 93    Mystic_Woods_by_The_Butterfly_Conservatory_Of
# 94    Hollywood_Fashion
# 95    The_Mallikarjun_Temple-Canacona_South
# 96    Rajbagh_Beach-Panjim_North
# 97    Sandalwood_Ayurveda-Cavelossim_South
# 98    Bhagwan_Mahavir_Wildlife_Sanctuary-South
# 99    Rock_Formations-Agonda_South
